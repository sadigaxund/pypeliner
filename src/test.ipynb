# %%
import requests

url = "https://priceline-com-provider.p.rapidapi.com/v2/hotels/details"

querystring = {
    "hotel_id": "700008849",
    "videos": "true",
    "important_info": "true",
    "recent": "true",
    "photos": "true",
    "plugins": "true",
    "reviews": "false",
    "promo": "true",
    "guest_score_breakdown": "true",
    "nearby": "true",
    "id_lookup": "false",
}

headers = {
    "X-RapidAPI-Key": "14d96c6fc2msh7414df2fb7e40ddp10513djsn985426003f23",
    "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com",
}

response = requests.get(url, headers=headers, params=querystring)

print()
# Out:
# {'getHotelHotelDetails': {'results': {'status': 'Success', 'status_code': 100, 'hotel_data': {'hotel_0': {'id': '700008849', 'id_a': '2544429', 'id_b': '21794', 'id_t': '49229', 'id_r': None, 'id_g': 'd0145485-94a6-4449-8ff6-ec457b9c42db', 'active': True, 'inventory': {'inventory_0': 'agoda', 'inventory_1': 'booking', 'inventory_2': 'tweb', 'inventory_3': 'gar'}, 'name': 'Sheraton Austin Hotel at the Capitol', 'property_type': 'Hotel', 'property_type_id': 14, 'semi_opq_enabled': 1, 'star_rating': '3.5', 'review_rating': 6.6, 'review_rating_desc': 'Pleasant', 'review_count': 742, 'rating_count': 742, 'review_source': '', 'booking_review_url': '', 'agoda_review_url': '', 'agoda_url': 'https://www.agoda.com/partners/partnersearch.aspx?hid=2544429', 'booking_url': 'https://www.booking.com/hotel/us/sheraton-austin-hotel-at-the-capitol.html', 'priceline_url': 'https://www.priceline.com/r/?channel=PPN&product=hotel&theme=Nodatedetails&hotelid=49229&rooms=1', 'static_low_rate': {'source_curr
# ...

# %%
response.json()["getHotelHotelDetails"]["results"]["hotel_data"]["hotel_0"]
# Out:
# {'id': '700008849',
#  'id_a': '2544429',
#  'id_b': '21794',
#  'id_t': '49229',
#  'id_r': None,
#  'id_g': 'd0145485-94a6-4449-8ff6-ec457b9c42db',
#  'active': True,
#  'inventory': {'inventory_0': 'agoda',
#   'inventory_1': 'booking',
#   'inventory_2': 'tweb',
#   'inventory_3': 'gar'},
#  'name': 'Sheraton Austin Hotel at the Capitol',
#  'property_type': 'Hotel',
#  'property_type_id': 14,
#  'semi_opq_enabled': 1,
#  'star_rating': '3.5',
#  'review_rating': 6.6,
#  'review_rating_desc': 'Pleasant',
#  'review_count': 742,
#  'rating_count': 742,
#  'review_source': '',
#  'booking_review_url': '',
#  'agoda_review_url': '',
#  'agoda_url': 'https://www.agoda.com/partners/partnersearch.aspx?hid=2544429',
#  'booking_url': 'https://www.booking.com/hotel/us/sheraton-austin-hotel-at-the-capitol.html',
#  'priceline_url': 'https://www.priceline.com/r/?channel=PPN&product=hotel&theme=Nodatedetails&hotelid=49229&rooms=1',
#  'static_low_rate': {'source_currency': None,
# ...

# %%
import requests

url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/details"

querystring = {"hotel_id": "49229"}

headers = {
    "X-RapidAPI-Key": "14d96c6fc2msh7414df2fb7e40ddp10513djsn985426003f23",
    "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com",
}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'hotelId': '49229',
#  'name': 'Sheraton Austin Hotel at the Capitol',
#  'brand': 'Sheraton',
#  'brandId': '23',
#  'description': 'Centrally located in downtown Austin, this hotel is within walking distance of the Red River Music District. Rooms with 32-inch flat-screen TVs are featured. The spacious guest rooms at the Austin Sheraton Hotel offer modern furnishings and cable TV. A work desk and coffee maker are provided for added convenience. The Yard, a southwestern-style restaurant, is located on-site. Guests can enjoy breakfast, lunch and dinner inside or on the outdoor patio. Drinks are available at both the Lobby Bar and Coffee Bar. Sheraton at the Capitol Austin offers a 24-hour business center. The Austin Convention Center and Austin Children’s Museum are a 15-minute walk from the Sheraton Austin. Shopping on 6th Street is within walking distance. ',
#  'starRating': 3.5,
#  'propertyTypeId': 204,
#  'location': {'address': {'addressLine1': '701 East 11th Street',
# ...

# %%
import requests

url = "https://priceline-com-provider.p.rapidapi.com/v2/hotels/downloadHotels"

querystring = {"country_code": "sa", "resume_key": "", "limit": 100}

headers = {
    "X-RapidAPI-Key": "14d96c6fc2msh7414df2fb7e40ddp10513djsn985426003f23",
    "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com",
}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'getSharedBOF2.Downloads.Hotel.Hotels': {'results': {'status': 'Success',
#    'status_code': 100,
#    'resume_key': '_TeCj2hbXjF43rmjatEgRKYtf-mks7pNagB4oWQWYA68bQD3K8gRjFi8afKn2tkHE75-i4jDwWOCcjOYn__pYgpXzh_xSCIgecfvAadPhRJ2hzH881_AFFJeMBX2qG5bh',
#    'hotels': {'hotel_0': {'hotelid_ppn': '700009949',
#      'hotelid_a': '59689',
#      'hotelid_b': '23198',
#      'hotelid_t': '15254704',
#      'hotel_type': 'Hotel',
#      'property_type_id': '14',
#      'hotel_name': 'Mandarin Oriental Al Faisaliah Riyadh',
#      'hotel_address': 'King Fahad Road Olaya',
#      'city': 'Riyadh',
# ...

# %%
import requests

url = "https://priceline-com-provider.p.rapidapi.com/v1/hotels/booking-details"

querystring = {
    "hotel_id": "49229",
    "date_checkout": "2060-12-31",
    "date_checkin": "2050-01-31",
}

headers = {
    "X-RapidAPI-Key": "14d96c6fc2msh7414df2fb7e40ddp10513djsn985426003f23",
    "X-RapidAPI-Host": "priceline-com-provider.p.rapidapi.com",
}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'hotelId': '49229',
#  'name': 'Sheraton Austin Hotel at the Capitol',
#  'brand': 'Sheraton',
#  'brandId': '23',
#  'description': 'Centrally located in downtown Austin, this hotel is within walking distance of the Red River Music District. Rooms with 32-inch flat-screen TVs are featured. The spacious guest rooms at the Austin Sheraton Hotel offer modern furnishings and cable TV. A work desk and coffee maker are provided for added convenience. The Yard, a southwestern-style restaurant, is located on-site. Guests can enjoy breakfast, lunch and dinner inside or on the outdoor patio. Drinks are available at both the Lobby Bar and Coffee Bar. Sheraton at the Capitol Austin offers a 24-hour business center. The Austin Convention Center and Austin Children’s Museum are a 15-minute walk from the Sheraton Austin. Shopping on 6th Street is within walking distance. ',
#  'starRating': 3.5,
#  'propertyTypeId': 204,
#  'location': {'address': {'addressLine1': '701 East 11th Street',
# ...

# %%
# Out:
# {'hotelId': '6733503',
#  'name': 'Happy go Lucky Hotel  Hostel',
#  'brand': 'Independent',
#  'brandId': '0',
#  'description': "Just 5 minutes from Berlin’s famous Kurfürstendamm boulevard, Happy go Lucky Hotel + Hostel is located in Charlottenburg. It enjoys fast connections to all major sights, the ICC exhibition center, and Tegel Airport. Free WiFi is available in public areas. Set in a traditional Berlin building, Happy go Lucky Hotel + Hostel offers functional, nonsmoking rooms with shared facilities. Reception is open 24/7. A breakfast buffet is served each morning from 07:00 until 11:00 at an additional charge. Lunch packs are also available. The Charlottenburg S-Bahn (city rail) Train Station is just steps away from the Happy go Lucky. This offers quick connections to all of Berlin's main sights and landmarks, including Berlin Main Station and Alexanderplatz. ",
#  'starRating': 2.0,
#  'propertyTypeId': 203,
# ...
